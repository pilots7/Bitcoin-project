# %%
import pandas as pd
import numpy as np

# %%
bitcoin=pd.read_csv('bitcoin_dataset.csv')

# %%
bitcoin.head()
# Out:
#                   Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2010-02-23 00:00:00               0.0           2110700.0             0.0
# 1  2010-02-24 00:00:00               0.0           2120200.0             0.0
# 2  2010-02-25 00:00:00               0.0           2127600.0             0.0
# 3  2010-02-26 00:00:00               0.0           2136100.0             0.0
# 4  2010-02-27 00:00:00               0.0           2144750.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000216
# 1               0.0              0.0            0.000282
# 2               0.0              0.0            0.000227
# 3               0.0              0.0            0.000319
# 4               0.0              0.0            0.000223
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                    0.0                           1.0
# 1                    0.0                           1.0
# 2                    0.0                           1.0
# 3                    0.0                           1.0
# 4                    0.0                           1.0
#
#    btc_median_confirmation_time  ...  btc_cost_per_transaction_percent  \
# 0                           0.0  ...                      25100.000000
# 1                           0.0  ...                        179.245283
# 2                           0.0  ...                       1057.142857
# 3                           0.0  ...                         64.582059
# 4                           0.0  ...                       1922.222222
#
#    btc_cost_per_transaction  btc_n_unique_addresses  btc_n_transactions  \
# 0                       0.0                   252.0               252.0
# 1                       0.0                   195.0               196.0
# 2                       0.0                   150.0               150.0
# 3                       0.0                   176.0               176.0
# 4                       0.0                   176.0               176.0
#
#    btc_n_transactions_total  btc_n_transactions_excluding_popular  \
# 0                   42613.0                                 252.0
# 1                   42809.0                                 196.0
# 2                   42959.0                                 150.0
# 3                   43135.0                                 176.0
# 4                   43311.0                                 176.0
#
#    btc_n_transactions_excluding_chains_longer_than_100  btc_output_volume  \
# 0                                              252.0              12600.0
# 1                                              196.0              14800.0
# 2                                              150.0               8100.0
# 3                                              176.0              29349.0
# 4                                              176.0               9101.0
#
#    btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# 0                              50.0                                   0.0
# 1                            5300.0                                   0.0
# 2                             700.0                                   0.0
# 3                           13162.0                                   0.0
# 4                             450.0                                   0.0
#
# [5 rows x 24 columns]

# %%
bitcoin.describe()
# Out:
#        btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# count       2920.000000        2.920000e+03    2.920000e+03      2.899000e+03
# mean         897.485562        1.152051e+07    1.443022e+10      8.231157e+07
# std         2400.159935        4.200938e+06    4.029263e+10      3.116642e+08
# min            0.000000        2.110700e+06    0.000000e+00      0.000000e+00
# 25%            6.768750        8.405100e+06    5.560588e+07      2.994316e+05
# 50%          236.310000        1.242910e+07    3.364730e+09      1.024364e+07
# 75%          603.909050        1.523764e+07    8.210042e+09      2.934823e+07
# max        19498.683333        1.687682e+07    3.265254e+11      5.352016e+09
#
#        btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# count      2920.000000         2920.000000            2920.000000
# mean      36058.374765            0.355733               0.362329
# std       44536.901058            0.356388               0.840614
# min           0.000000            0.000216               0.000000
# 25%         777.250000            0.024595               0.000000
# 50%       15132.000000            0.199806               0.000000
# 75%       59301.750000            0.688036               0.000000
# max      157664.996336            1.110327               7.000000
#
#        btc_n_transactions_per_block  btc_median_confirmation_time  \
# count                   2920.000000                   2920.000000
# mean                     677.010924                      7.547221
# std                      689.042018                      4.956135
# min                        1.000000                      0.000000
# 25%                       55.000000                      6.129167
# 50%                      378.500000                      7.933333
# 75%                     1238.569055                     10.237500
# max                     2722.625000                     47.733333
#
#        btc_hash_rate  ...  btc_cost_per_transaction_percent  \
# count   2.920000e+03  ...                       2920.000000
# mean    1.387725e+06  ...                         58.079229
# std     3.379005e+06  ...                       1709.115660
# min     2.657847e-05  ...                          0.136531
# 25%     1.169741e+01  ...                          1.180738
# 50%     2.640642e+04  ...                          2.461625
# 75%     1.097174e+06  ...                          5.844059
# max     2.557925e+07  ...                      88571.428571
#
#        btc_cost_per_transaction  btc_n_unique_addresses  btc_n_transactions  \
# count               2920.000000            2.920000e+03         2920.000000
# mean                  15.237677            1.959608e+05       102922.695548
# std                   21.638354            2.093837e+05       103846.693961
# min                    0.000000            1.100000e+02          118.000000
# 25%                    4.220581            1.719000e+04         8157.000000
# 50%                    7.865943            1.325365e+05        63006.000000
# 75%                   15.285634            3.666370e+05       191465.250000
# max                  161.686071            1.072861e+06       490644.000000
#
#        btc_n_transactions_total  btc_n_transactions_excluding_popular  \
# count              2.920000e+03                           2920.000000
# mean               7.016399e+07                          95187.560616
# std                8.475145e+07                         103941.129363
# min                4.261300e+04                            118.000000
# 25%                2.484693e+06                           6995.500000
# 50%                3.340692e+07                          55015.500000
# 75%                1.116330e+08                         187182.750000
# max                3.005766e+08                         470650.000000
#
#        btc_n_transactions_excluding_chains_longer_than_100  btc_output_volume  \
# count                                        2920.000000         2.920000e+03
# mean                                        63770.210274         1.568570e+06
# std                                         69733.896388         2.272542e+06
# min                                           118.000000         6.150000e+03
# 25%                                          6888.750000         4.975323e+05
# 50%                                         35670.000000         1.118162e+06
# 75%                                        114920.000000         2.028524e+06
# max                                        318896.000000         4.599222e+07
#
#        btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# count                      2.920000e+03                          2.920000e+03
# mean                       2.038262e+05                          2.118495e+08
# std                        2.675688e+05                          5.903811e+08
# min                        7.000000e+00                          0.000000e+00
# 25%                        9.660900e+04                          9.889582e+05
# 50%                        1.787410e+05                          3.899174e+07
# 75%                        2.587235e+05                          1.369944e+08
# max                        5.825066e+06                          5.760245e+09
#
# [8 rows x 23 columns]

# %%
bitcoin.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                      0
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                         0
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                            0
# btc_hash_rate                                           0
# btc_difficulty                                          0
# btc_miners_revenue                                      0
# btc_transaction_fees                                    0
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# btc_n_unique_addresses                                  0
# btc_n_transactions                                      0
# btc_n_transactions_total                                0
# 486                                              7349.0         4.528661e+06
# 487                                              6942.0         6.997337e+06
# 1302                                            25426.0         6.727934e+05
# 1342                                            24573.0         5.055125e+05
# 1536                                            37223.0         1.352520e+06
# 1560                                            38612.0         7.112488e+05
# 1561                                            39890.0         1.139172e+06
# 1620                                            42628.0         4.676377e+05
# 1622                                            34386.0         4.443793e+05
# 1624                                            47113.0         5.295149e+05
# 1659                                            44529.0         4.881900e+05
# 1678                                            32727.0         4.538058e+05
# 1697                                            40959.0         9.417440e+05
# 1732                                            43835.0         1.154315e+06
# 1779                                            49400.0         1.286464e+06
# 1806                                            50952.0         1.169774e+06
# 2018                                            76848.0         1.211736e+06
#
#       btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# 482                           836861.0                            14519535.0
# 483                           114264.0                             1771098.0
# 484                           122507.0                             1843731.0
# 485                           475995.0                             7615913.0
# 486                           106146.0                             1777963.0
# 487                           110463.0                             1944141.0
# 1302                          137920.0                            17593089.0
# 1342                          107717.0                            20364921.0
# 1536                           80315.0                            36304065.0
# 1560                           87513.0                            55263584.0
# 1561                          124768.0                            84081482.0
# 1620                          166173.0                           100025886.0
# 1622                           49181.0                            29006666.0
# 1624                          136298.0                            79081409.0
# 1659                          111317.0                            51927046.0
# 1678                           92933.0                            35314615.0
# 1697                          142251.0                            54457847.0
# 1732                          161082.0                            57490040.0
# 1779                          256344.0                            70955899.0
# 1806                          213538.0                            50503768.0
# 2018                          256023.0                            58224697.0
#
# [21 rows x 24 columns]

# %%
# Drop na's
bitcoin.dropna(inplace=True)

# %%
bitcoin[bitcoin['btc_trade_volume'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, btc_market_price, btc_total_bitcoins, btc_market_cap, btc_trade_volume, btc_blocks_size, btc_avg_block_size, btc_n_orphaned_blocks, btc_n_transactions_per_block, btc_median_confirmation_time, btc_hash_rate, btc_difficulty, btc_miners_revenue, btc_transaction_fees, btc_cost_per_transaction_percent, btc_cost_per_transaction, btc_n_unique_addresses, btc_n_transactions, btc_n_transactions_total, btc_n_transactions_excluding_popular, btc_n_transactions_excluding_chains_longer_than_100, btc_output_volume, btc_estimated_transaction_volume, btc_estimated_transaction_volume_usd]
# Index: []
#
# [0 rows x 24 columns]

# %%
bitcoin.shape
# Out:
# (2899, 24)

# %%
bitcoin.size
# Out:
# 69576

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2899 entries, 0 to 2919
# Data columns (total 24 columns):
# Date                                                   2899 non-null object
# btc_market_price                                       2899 non-null float64
# btc_total_bitcoins                                     2899 non-null float64
# btc_market_cap                                         2899 non-null float64
# btc_trade_volume                                       2899 non-null float64
# btc_blocks_size                                        2899 non-null float64
# btc_avg_block_size                                     2899 non-null float64
# btc_n_orphaned_blocks                                  2899 non-null float64
# btc_n_transactions_per_block                           2899 non-null float64
# btc_median_confirmation_time                           2899 non-null float64
# btc_hash_rate                                          2899 non-null float64
# btc_difficulty                                         2899 non-null float64
# btc_miners_revenue                                     2899 non-null float64
# btc_transaction_fees                                   2899 non-null float64
# btc_cost_per_transaction_percent                       2899 non-null float64
# btc_cost_per_transaction                               2899 non-null float64
# btc_n_unique_addresses                                 2899 non-null float64
# btc_n_transactions                                     2899 non-null float64
# btc_n_transactions_total                               2899 non-null float64
# btc_n_transactions_excluding_popular                   2899 non-null float64
# btc_n_transactions_excluding_chains_longer_than_100    2899 non-null float64
# btc_output_volume                                      2899 non-null float64
# btc_estimated_transaction_volume                       2899 non-null float64
# btc_estimated_transaction_volume_usd                   2899 non-null float64
# dtypes: float64(23), object(1)
# memory usage: 566.2+ KB

# %%
# Drop the dates
bitcoin.drop(["Date"],axis=1,inplace=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
bitcoin.hist(bins=100, figsize=(20,15))
plt.show()

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(bitcoin, test_size=0.2, random_state=42)

# %%
len(train_set)
# Out:
# 2319

# %%
train_set.head()
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 1927          225.5400          14235150.0    3.210596e+09      1.131495e+07
# 163             0.0000           3627950.0    0.000000e+00      3.020442e+02
# 1957          257.9200          14345600.0    3.700017e+09      1.078173e+07
# 252             0.1955           4460000.0    8.719300e+05      1.112144e+03
# 2252          459.4000          15469775.0    7.106815e+09      2.935363e+07
#
#       btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 1927     36420.000000            0.457110                    2.0
# 163          1.000000            0.000887                    0.0
# 1957     38418.000000            0.405146                    7.0
# 252          1.000000            0.000475                    0.0
# 2252     66022.678047            0.728040                    0.0
#
#       btc_n_transactions_per_block  btc_median_confirmation_time  \
# 1927                    713.000000                      9.050000
# 163                       1.000000                      0.000000
# 1957                   1356.000000                      7.333333
# 252                       1.000000                      0.000000
# 2252                   1387.537879                      8.783333
#
#       btc_hash_rate  ...  btc_cost_per_transaction_percent  \
# 1927   3.359282e+05  ...                          1.722481
# 163    2.962137e-03  ...                         66.298295
# 1957   3.806471e+05  ...                          2.291255
# 252    2.582010e-02  ...                         32.992619
# 2252   1.172443e+06  ...                          1.385967
#
#       btc_cost_per_transaction  btc_n_unique_addresses  btc_n_transactions  \
# 1927                  6.493516                240222.0            123893.0
# 163                   0.000000                   787.0               604.0
# 1957                  8.786112                250207.0            114310.0
# 252                   5.802827                   321.0               283.0
# 2252                  8.360698                376201.0            183155.0
#
#       btc_n_transactions_total  btc_n_transactions_excluding_popular  \
# 1927                70958001.0                              117311.0
# 163                   100189.0                                 604.0
# 1957                74494223.0                              104771.0
# 252                   138026.0                                 283.0
# 2252               124458860.0                              213799.0
#
#       btc_n_transactions_excluding_chains_longer_than_100  btc_output_volume  \
# 1927                                            62608.0         1.277219e+06
# 163                                               460.0         6.319635e+04
# 1957                                            55637.0         1.036174e+06
# 252                                               283.0         6.517114e+04
# 2252                                           115683.0         2.223870e+06
#
#       btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# 1927                     207085.000000                          4.670595e+07
# 163                       18402.000000                          0.000000e+00
# 1957                     169951.000000                          4.383364e+07
# 252                       25460.000000                          4.977000e+03
# 2252                     240501.291193                          1.104863e+08
#
# [5 rows x 23 columns]

# %%
test_set.head()
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 141               0.00           3366650.0    0.000000e+00      0.000000e+00
# 1568            649.89          12878750.0    8.369771e+09      1.323817e+07
# 491              17.30           6694650.0    1.158174e+08      3.552121e+05
# 1729            379.91          13515175.0    5.134550e+09      3.070683e+07
# 2270            454.70          15537575.0    7.064935e+09      2.265272e+07
#
#       btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 141          1.000000            0.002653                    0.0
# 1568     19154.000000            0.227907                    2.0
# 491        184.000000            0.023998                    0.0
# 1729     25681.000000            0.331471                    0.0
# 2270     68037.456408            0.779994                    0.0
#
#       btc_n_transactions_per_block  btc_median_confirmation_time  \
# 141                       2.000000                      0.000000
# 1568                    289.000000                      6.750000
# 491                      57.000000                      0.000000
# 1729                    532.000000                      8.000000
# 2270                   1643.230216                      8.283333
#
#       btc_hash_rate  ...  btc_cost_per_transaction_percent  \
# 141    1.295025e-03  ...                         67.558215
# 1568   1.034426e+05  ...                          2.569898
# 491    1.213512e+01  ...                         11.243137
# 1729   2.953063e+05  ...                          1.630618
# 2270   1.342248e+06  ...                          1.012910
#
#       btc_cost_per_transaction  btc_n_unique_addresses  btc_n_transactions  \
# 141                   0.000000                  6109.0              5659.0
# 1568                 44.050747                150796.0             65460.0
# 491                  15.106419                 21640.0             10158.0
# 1729                 16.333821                176768.0             87524.0
# 2270                  7.010848                377121.0            228409.0
#
#       btc_n_transactions_total  btc_n_transactions_excluding_popular  \
# 141                    83298.0                                5659.0
# 1568                40457902.0                               59436.0
# 491                   899070.0                               10158.0
# 1729                51751239.0                               79411.0
# 2270               128562103.0                              229246.0
#
#       btc_n_transactions_excluding_chains_longer_than_100  btc_output_volume  \
# 141                                               951.0         4.570562e+05
# 1568                                            36076.0         6.148946e+05
# 491                                              8755.0         5.122235e+06
# 1729                                            45342.0         1.003526e+06
# 2270                                           135621.0         2.295414e+06
#
#       btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# 141                       42482.000000                          0.000000e+00
# 1568                     172653.000000                          1.122053e+08
# 491                       78893.000000                          1.364842e+06
# 1729                     230771.000000                          8.767238e+07
# 2270                     347686.569036                          1.580931e+08
#
# [5 rows x 23 columns]

# %%
corr_matrix = bitcoin.corr()

# %%
type(corr_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_matrix
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.405682
# btc_market_cap                                              0.999800
# btc_trade_volume                                            0.866398
# btc_blocks_size                                             0.693590
# btc_avg_block_size                                          0.558899
# btc_n_orphaned_blocks                                      -0.083591
# btc_n_transactions_per_block                                0.539137
# btc_median_confirmation_time                                0.274498
# btc_hash_rate                                               0.904198
# btc_difficulty                                              0.900685
# btc_miners_revenue                                          0.985424
# btc_transaction_fees                                        0.778910
# btc_cost_per_transaction_percent                           -0.012474
# btc_cost_per_transaction                                    0.832507
# btc_n_unique_addresses                                      0.661161
# btc_n_transactions                                          0.564382
# btc_n_transactions_total                                    0.698476
# btc_n_transactions_excluding_popular                        0.554003
# btc_n_transactions_excluding_chains_longer_than...          0.565298
# btc_output_volume                                           0.105984
# btc_estimated_transaction_volume                            0.045032
# btc_estimated_transaction_volume_usd                        0.960013
#
#                                                     btc_total_bitcoins  \
# btc_market_price                                              0.405682
# btc_total_bitcoins                                            1.000000
# btc_market_cap                                                0.398157
# btc_trade_volume                                              0.300300
# btc_blocks_size                                               0.780954
# btc_avg_block_size                                            0.855230
# btc_n_orphaned_blocks                                         0.270728
# btc_n_transactions_per_block                                  0.834680
# btc_median_confirmation_time                                  0.670069
# btc_hash_rate                                                 0.474752
# btc_difficulty                                                0.484575
# btc_miners_revenue                                            0.396498
# btc_transaction_fees                                          0.474413
# btc_cost_per_transaction_percent                             -0.070871
# btc_cost_per_transaction                                      0.385010
# btc_n_unique_addresses                                        0.824687
# btc_n_transactions                                            0.836221
# btc_n_transactions_total                                      0.784885
# btc_n_transactions_excluding_popular                          0.818271
# btc_n_transactions_excluding_chains_longer_than...            0.804737
# btc_output_volume                                             0.294050
# btc_estimated_transaction_volume                              0.213148
# btc_estimated_transaction_volume_usd                          0.399375
#
#                                                     btc_market_cap  \
# btc_market_price                                          0.999800
# btc_total_bitcoins                                        0.398157
# btc_market_cap                                            1.000000
# btc_trade_volume                                          0.866953
# btc_blocks_size                                           0.692098
# btc_avg_block_size                                        0.556367
# btc_n_orphaned_blocks                                    -0.087663
# btc_n_transactions_per_block                              0.536612
# btc_median_confirmation_time                              0.271277
# btc_hash_rate                                             0.905896
# btc_difficulty                                            0.902346
# btc_miners_revenue                                        0.984026
# btc_transaction_fees                                      0.778767
# btc_cost_per_transaction_percent                         -0.011966
# btc_cost_per_transaction                                  0.823891
# btc_n_unique_addresses                                    0.657910
# btc_n_transactions                                        0.561538
# btc_n_transactions_total                                  0.696759
# btc_n_transactions_excluding_popular                      0.551176
# btc_n_transactions_excluding_chains_longer_than...        0.562740
# btc_output_volume                                         0.106497
# btc_estimated_transaction_volume                          0.045384
# btc_estimated_transaction_volume_usd                      0.959919
#
#                                                     btc_trade_volume  \
# btc_market_price                                            0.866398
# btc_total_bitcoins                                          0.300300
# btc_market_cap                                              0.866953
# btc_trade_volume                                            1.000000
# btc_blocks_size                                             0.545804
# btc_avg_block_size                                          0.434405
# btc_n_orphaned_blocks                                      -0.075811
# btc_n_transactions_per_block                                0.425024
# btc_median_confirmation_time                                0.212372
# btc_hash_rate                                               0.771285
# btc_difficulty                                              0.765098
# btc_miners_revenue                                          0.867913
# btc_transaction_fees                                        0.699080
# btc_cost_per_transaction_percent                           -0.008829
# btc_cost_per_transaction                                    0.706829
# btc_n_unique_addresses                                      0.537056
# btc_n_transactions                                          0.448603
# btc_n_transactions_total                                    0.549726
# btc_n_transactions_excluding_popular                        0.438016
# btc_n_transactions_excluding_chains_longer_than...          0.448148
# btc_output_volume                                           0.090512
# btc_estimated_transaction_volume                            0.051456
# btc_estimated_transaction_volume_usd                        0.887508
#
#                                                     btc_blocks_size  \
# btc_market_price                                           0.693590
# btc_total_bitcoins                                         0.780954
# btc_market_cap                                             0.692098
# btc_trade_volume                                           0.545804
# btc_blocks_size                                            1.000000
# btc_avg_block_size                                         0.955453
# btc_n_orphaned_blocks                                      0.045198
# btc_n_transactions_per_block                               0.935793
# btc_median_confirmation_time                               0.501127
# btc_hash_rate                                              0.807544
# btc_difficulty                                             0.820361
# btc_miners_revenue                                         0.641869
# btc_transaction_fees                                       0.731795
# btc_cost_per_transaction_percent                          -0.027009
# btc_cost_per_transaction                                   0.483790
# btc_n_unique_addresses                                     0.959868
# btc_n_transactions                                         0.939816
# btc_n_transactions_total                                   0.999797
# btc_n_transactions_excluding_popular                       0.941813
# btc_n_transactions_excluding_chains_longer_than...         0.952524
# btc_output_volume                                          0.246048
# btc_estimated_transaction_volume                           0.147914
# btc_estimated_transaction_volume_usd                       0.683286
#
#                                                     btc_avg_block_size  \
# btc_market_price                                              0.558899
# btc_total_bitcoins                                            0.855230
# btc_market_cap                                                0.556367
# btc_trade_volume                                              0.434405
# btc_blocks_size                                               0.955453
# btc_avg_block_size                                            1.000000
# btc_n_orphaned_blocks                                         0.140242
# btc_n_transactions_per_block                                  0.974133
# btc_median_confirmation_time                                  0.552412
# btc_hash_rate                                                 0.664902
# btc_difficulty                                                0.680269
# btc_miners_revenue                                            0.520821
# btc_transaction_fees                                          0.649420
# btc_cost_per_transaction_percent                             -0.033151
# btc_cost_per_transaction                                      0.363889
# btc_n_unique_addresses                                        0.966453
# btc_n_transactions                                            0.974526
# btc_n_transactions_total                                      0.953783
# btc_n_transactions_excluding_popular                          0.972859
# btc_n_transactions_excluding_chains_longer_than...            0.967051
# btc_output_volume                                             0.293714
# btc_estimated_transaction_volume                              0.187329
# btc_estimated_transaction_volume_usd                          0.564268
#
#                                                     btc_n_orphaned_blocks  \
# btc_market_price                                                -0.083591
# btc_total_bitcoins                                               0.270728
# btc_market_cap                                                  -0.087663
# btc_trade_volume                                                -0.075811
# btc_blocks_size                                                  0.045198
# btc_avg_block_size                                               0.140242
# btc_n_orphaned_blocks                                            1.000000
# btc_n_transactions_per_block                                     0.112323
# btc_median_confirmation_time                                     0.066502
# btc_hash_rate                                                   -0.097038
# btc_difficulty                                                  -0.097771
# btc_miners_revenue                                              -0.059547
# btc_transaction_fees                                            -0.095773
# btc_cost_per_transaction_percent                                -0.014016
# btc_cost_per_transaction                                        -0.005037
# btc_n_unique_addresses                                           0.118016
# btc_n_transactions                                               0.106119
# btc_n_transactions_total                                         0.045439
# btc_n_transactions_excluding_popular                             0.113774
# btc_n_transactions_excluding_chains_longer_than...               0.071380
# btc_output_volume                                               -0.004205
# btc_estimated_transaction_volume                                 0.019804
# btc_estimated_transaction_volume_usd                            -0.085715
#
#                                                     btc_n_transactions_per_block  \
# btc_market_price                                                        0.539137
# btc_total_bitcoins                                                      0.834680
# btc_market_cap                                                          0.536612
# btc_trade_volume                                                        0.425024
# btc_blocks_size                                                         0.935793
# btc_avg_block_size                                                      0.974133
# btc_n_orphaned_blocks                                                   0.112323
# btc_n_transactions_per_block                                            1.000000
# btc_median_confirmation_time                                            0.560280
# btc_hash_rate                                                           0.611114
# btc_difficulty                                                          0.630854
# btc_miners_revenue                                                      0.505442
# btc_transaction_fees                                                    0.671442
# btc_cost_per_transaction_percent                                       -0.032609
# btc_cost_per_transaction                                                0.322084
# btc_n_unique_addresses                                                  0.966230
# btc_n_transactions                                                      0.980680
# btc_n_transactions_total                                                0.934109
# btc_n_transactions_excluding_popular                                    0.976379
# btc_n_transactions_excluding_chains_longer_than...                      0.975031
# btc_output_volume                                                       0.298225
# btc_estimated_transaction_volume                                        0.187031
# btc_estimated_transaction_volume_usd                                    0.563983
#
#                                                     btc_median_confirmation_time  \
# btc_market_price                                                        0.274498
# btc_total_bitcoins                                                      0.670069
# btc_market_cap                                                          0.271277
# btc_trade_volume                                                        0.212372
# btc_blocks_size                                                         0.501127
# btc_avg_block_size                                                      0.552412
# btc_n_orphaned_blocks                                                   0.066502
# btc_n_transactions_per_block                                            0.560280
# btc_median_confirmation_time                                            1.000000
# btc_hash_rate                                                           0.315635
# btc_difficulty                                                          0.336845
# btc_miners_revenue                                                      0.249738
# btc_transaction_fees                                                    0.417863
# btc_cost_per_transaction_percent                                       -0.049860
# btc_cost_per_transaction                                                0.180178
# btc_n_unique_addresses                                                  0.514073
# btc_n_transactions                                                      0.545789
# btc_n_transactions_total                                                0.506412
# btc_n_transactions_excluding_popular                                    0.511144
# btc_n_transactions_excluding_chains_longer_than...                      0.535525
# btc_output_volume                                                       0.311178
# btc_estimated_transaction_volume                                        0.216145
# btc_estimated_transaction_volume_usd                                    0.283796
#
#                                                     btc_hash_rate  ...  \
# btc_market_price                                         0.904198  ...
# btc_total_bitcoins                                       0.474752  ...
# btc_market_cap                                           0.905896  ...
# btc_trade_volume                                         0.771285  ...
# btc_blocks_size                                          0.807544  ...
# btc_avg_block_size                                       0.664902  ...
# btc_n_orphaned_blocks                                   -0.097038  ...
# btc_n_transactions_per_block                             0.611114  ...
# btc_median_confirmation_time                             0.315635  ...
# btc_hash_rate                                            1.000000  ...
# btc_difficulty                                           0.991076  ...
# btc_miners_revenue                                       0.853746  ...
# btc_transaction_fees                                     0.711672  ...
# btc_cost_per_transaction_percent                        -0.013790  ...
# btc_cost_per_transaction                                 0.729981  ...
# btc_n_unique_addresses                                   0.711640  ...
# btc_n_transactions                                       0.638483  ...
# btc_n_transactions_total                                 0.810448  ...
# btc_n_transactions_excluding_popular                     0.632901  ...
# btc_n_transactions_excluding_chains_longer_than...       0.655261  ...
# btc_output_volume                                        0.137671  ...
# btc_estimated_transaction_volume                         0.065245  ...
# btc_estimated_transaction_volume_usd                     0.843074  ...
#
#                                                     btc_cost_per_transaction_percent  \
# btc_market_price                                                           -0.012474
# btc_total_bitcoins                                                         -0.070871
# btc_market_cap                                                             -0.011966
# btc_trade_volume                                                           -0.008829
# btc_blocks_size                                                            -0.027009
# btc_avg_block_size                                                         -0.033151
# btc_n_orphaned_blocks                                                      -0.014016
# btc_n_transactions_per_block                                               -0.032609
# btc_median_confirmation_time                                               -0.049860
# btc_hash_rate                                                              -0.013790
# btc_difficulty                                                             -0.014103
# btc_miners_revenue                                                         -0.013125
# btc_transaction_fees                                                       -0.017283
# btc_cost_per_transaction_percent                                            1.000000
# btc_cost_per_transaction                                                   -0.022472
# btc_n_unique_addresses                                                     -0.031052
# btc_n_transactions                                                         -0.032878
# btc_n_transactions_total                                                   -0.027573
# btc_n_transactions_excluding_popular                                       -0.030411
# btc_n_transactions_excluding_chains_longer_than...                         -0.030342
# btc_output_volume                                                          -0.022431
# btc_estimated_transaction_volume                                           -0.024824
# btc_estimated_transaction_volume_usd                                       -0.012035
#
#                                                     btc_cost_per_transaction  \
# btc_market_price                                                    0.832507
# btc_total_bitcoins                                                  0.385010
# btc_market_cap                                                      0.823891
# btc_trade_volume                                                    0.706829
# btc_blocks_size                                                     0.483790
# btc_avg_block_size                                                  0.363889
# btc_n_orphaned_blocks                                              -0.005037
# btc_n_transactions_per_block                                        0.322084
# btc_median_confirmation_time                                        0.180178
# btc_hash_rate                                                       0.729981
# btc_difficulty                                                      0.720908
# btc_miners_revenue                                                  0.854554
# btc_transaction_fees                                                0.565866
# btc_cost_per_transaction_percent                                   -0.022472
# btc_cost_per_transaction                                            1.000000
# btc_n_unique_addresses                                              0.460723
# btc_n_transactions                                                  0.351507
# btc_n_transactions_total                                            0.493856
# btc_n_transactions_excluding_popular                                0.346280
# btc_n_transactions_excluding_chains_longer_than...                  0.349588
# btc_output_volume                                                   0.005678
# btc_estimated_transaction_volume                                   -0.021240
# btc_estimated_transaction_volume_usd                                0.751895
#
#                                                     btc_n_unique_addresses  \
# btc_market_price                                                  0.661161
# btc_total_bitcoins                                                0.824687
# btc_market_cap                                                    0.657910
# btc_trade_volume                                                  0.537056
# btc_blocks_size                                                   0.959868
# btc_avg_block_size                                                0.966453
# btc_n_orphaned_blocks                                             0.118016
# btc_n_transactions_per_block                                      0.966230
# btc_median_confirmation_time                                      0.514073
# btc_hash_rate                                                     0.711640
# btc_difficulty                                                    0.716092
# btc_miners_revenue                                                0.640150
# btc_transaction_fees                                              0.732275
# btc_cost_per_transaction_percent                                 -0.031052
# btc_cost_per_transaction                                          0.460723
# btc_n_unique_addresses                                            1.000000
# btc_n_transactions                                                0.982213
# btc_n_transactions_total                                          0.959586
# btc_n_transactions_excluding_popular                              0.981389
# btc_n_transactions_excluding_chains_longer_than...                0.973393
# btc_output_volume                                                 0.285209
# btc_estimated_transaction_volume                                  0.174912
# btc_estimated_transaction_volume_usd                              0.683188
#
#                                                     btc_n_transactions  \
# btc_market_price                                              0.564382
# btc_total_bitcoins                                            0.836221
# btc_market_cap                                                0.561538
# btc_trade_volume                                              0.448603
# btc_blocks_size                                               0.939816
# btc_avg_block_size                                            0.974526
# btc_n_orphaned_blocks                                         0.106119
# btc_n_transactions_per_block                                  0.980680
# btc_median_confirmation_time                                  0.545789
# btc_hash_rate                                                 0.638483
# btc_difficulty                                                0.642674
# btc_miners_revenue                                            0.541385
# btc_transaction_fees                                          0.685525
# btc_cost_per_transaction_percent                             -0.032878
# btc_cost_per_transaction                                      0.351507
# btc_n_unique_addresses                                        0.982213
# btc_n_transactions                                            1.000000
# btc_n_transactions_total                                      0.938678
# btc_n_transactions_excluding_popular                          0.993135
# btc_n_transactions_excluding_chains_longer_than...            0.989094
# btc_output_volume                                             0.311125
# btc_estimated_transaction_volume                              0.194895
# btc_estimated_transaction_volume_usd                          0.593972
#
#                                                     btc_n_transactions_total  \
# btc_market_price                                                    0.698476
# btc_total_bitcoins                                                  0.784885
# btc_market_cap                                                      0.696759
# btc_trade_volume                                                    0.549726
# btc_blocks_size                                                     0.999797
# btc_avg_block_size                                                  0.953783
# btc_n_orphaned_blocks                                               0.045439
# btc_n_transactions_per_block                                        0.934109
# btc_median_confirmation_time                                        0.506412
# btc_hash_rate                                                       0.810448
# btc_difficulty                                                      0.823186
# btc_miners_revenue                                                  0.647327
# btc_transaction_fees                                                0.736722
# btc_cost_per_transaction_percent                                   -0.027573
# btc_cost_per_transaction                                            0.493856
# btc_n_unique_addresses                                              0.959586
# btc_n_transactions                                                  0.938678
# btc_n_transactions_total                                            1.000000
# btc_n_transactions_excluding_popular                                0.939878
# btc_n_transactions_excluding_chains_longer_than...                  0.951359
# btc_output_volume                                                   0.244331
# btc_estimated_transaction_volume                                    0.146843
# btc_estimated_transaction_volume_usd                                0.687631
#
#                                                     btc_n_transactions_excluding_popular  \
# btc_market_price                                                                0.554003
# btc_total_bitcoins                                                              0.818271
# btc_market_cap                                                                  0.551176
# btc_trade_volume                                                                0.438016
# btc_blocks_size                                                                 0.941813
# btc_avg_block_size                                                              0.972859
# btc_n_orphaned_blocks                                                           0.113774
# btc_n_transactions_per_block                                                    0.976379
# btc_median_confirmation_time                                                    0.511144
# btc_hash_rate                                                                   0.632901
# btc_difficulty                                                                  0.637819
# btc_miners_revenue                                                              0.530302
# btc_transaction_fees                                                            0.671064
# btc_cost_per_transaction_percent                                               -0.030411
# btc_cost_per_transaction                                                        0.346280
# btc_n_unique_addresses                                                          0.981389
# btc_n_transactions                                                              0.993135
# btc_n_transactions_total                                                        0.939878
# btc_n_transactions_excluding_popular                                            1.000000
# btc_n_transactions_excluding_chains_longer_than...                              0.987157
# btc_output_volume                                                               0.295334
# btc_estimated_transaction_volume                                                0.187745
# btc_estimated_transaction_volume_usd                                            0.582607
#
#                                                     btc_n_transactions_excluding_chains_longer_than_100  \
# btc_market_price                                                                             0.565298
# btc_total_bitcoins                                                                           0.804737
# btc_market_cap                                                                               0.562740
# btc_trade_volume                                                                             0.448148
# btc_blocks_size                                                                              0.952524
# btc_avg_block_size                                                                           0.967051
# btc_n_orphaned_blocks                                                                        0.071380
# btc_n_transactions_per_block                                                                 0.975031
# btc_median_confirmation_time                                                                 0.535525
# btc_hash_rate                                                                                0.655261
# btc_difficulty                                                                               0.663015
# btc_miners_revenue                                                                           0.531172
# btc_transaction_fees                                                                         0.691555
# btc_cost_per_transaction_percent                                                            -0.030342
# btc_cost_per_transaction                                                                     0.349588
# btc_n_unique_addresses                                                                       0.973393
# btc_n_transactions                                                                           0.989094
# btc_n_transactions_total                                                                     0.951359
# btc_n_transactions_excluding_popular                                                         0.987157
# btc_n_transactions_excluding_chains_longer_than...                                           1.000000
# btc_output_volume                                                                            0.281097
# btc_estimated_transaction_volume                                                             0.183852
# btc_estimated_transaction_volume_usd                                                         0.590991
#
#                                                     btc_output_volume  \
# btc_market_price                                             0.105984
# btc_total_bitcoins                                           0.294050
# btc_market_cap                                               0.106497
# btc_trade_volume                                             0.090512
# btc_blocks_size                                              0.246048
# btc_avg_block_size                                           0.293714
# btc_n_orphaned_blocks                                       -0.004205
# btc_n_transactions_per_block                                 0.298225
# btc_median_confirmation_time                                 0.311178
# btc_hash_rate                                                0.137671
# btc_difficulty                                               0.139578
# btc_miners_revenue                                           0.099998
# btc_transaction_fees                                         0.182747
# btc_cost_per_transaction_percent                            -0.022431
# btc_cost_per_transaction                                     0.005678
# btc_n_unique_addresses                                       0.285209
# btc_n_transactions                                           0.311125
# btc_n_transactions_total                                     0.244331
# btc_n_transactions_excluding_popular                         0.295334
# btc_n_transactions_excluding_chains_longer_than...           0.281097
# btc_output_volume                                            1.000000
# btc_estimated_transaction_volume                             0.271360
# btc_estimated_transaction_volume_usd                         0.136394
#
#                                                     btc_estimated_transaction_volume  \
# btc_market_price                                                            0.045032
# btc_total_bitcoins                                                          0.213148
# btc_market_cap                                                              0.045384
# btc_trade_volume                                                            0.051456
# btc_blocks_size                                                             0.147914
# btc_avg_block_size                                                          0.187329
# btc_n_orphaned_blocks                                                       0.019804
# btc_n_transactions_per_block                                                0.187031
# btc_median_confirmation_time                                                0.216145
# btc_hash_rate                                                               0.065245
# btc_difficulty                                                              0.065549
# btc_miners_revenue                                                          0.043443
# btc_transaction_fees                                                        0.106960
# btc_cost_per_transaction_percent                                           -0.024824
# btc_cost_per_transaction                                                   -0.021240
# btc_n_unique_addresses                                                      0.174912
# btc_n_transactions                                                          0.194895
# btc_n_transactions_total                                                    0.146843
# btc_n_transactions_excluding_popular                                        0.187745
# btc_n_transactions_excluding_chains_longer_than...                          0.183852
# btc_output_volume                                                           0.271360
# btc_estimated_transaction_volume                                            1.000000
# btc_estimated_transaction_volume_usd                                        0.084458
#
#                                                     btc_estimated_transaction_volume_usd
# btc_market_price                                                                0.960013
# btc_total_bitcoins                                                              0.399375
# btc_market_cap                                                                  0.959919
# btc_trade_volume                                                                0.887508
# btc_blocks_size                                                                 0.683286
# btc_avg_block_size                                                              0.564268
# btc_n_orphaned_blocks                                                          -0.085715
# btc_n_transactions_per_block                                                    0.563983
# btc_median_confirmation_time                                                    0.283796
# btc_hash_rate                                                                   0.843074
# btc_difficulty                                                                  0.834812
# btc_miners_revenue                                                              0.956410
# btc_transaction_fees                                                            0.809442
# btc_cost_per_transaction_percent                                               -0.012035
# btc_cost_per_transaction                                                        0.751895
# btc_n_unique_addresses                                                          0.683188
# btc_n_transactions                                                              0.593972
# btc_n_transactions_total                                                        0.687631
# btc_n_transactions_excluding_popular                                            0.582607
# btc_n_transactions_excluding_chains_longer_than...                              0.590991
# btc_output_volume                                                               0.136394
# btc_estimated_transaction_volume                                                0.084458
# btc_estimated_transaction_volume_usd                                            1.000000
#
# [23 rows x 23 columns]

# %%
corr_matrix["btc_market_price"].sort_values(ascending=False)
# Out:
# btc_market_price                                       1.000000
# btc_market_cap                                         0.999800
# btc_miners_revenue                                     0.985424
# btc_estimated_transaction_volume_usd                   0.960013
# btc_hash_rate                                          0.904198
# btc_difficulty                                         0.900685
# btc_trade_volume                                       0.866398
# btc_cost_per_transaction                               0.832507
# btc_transaction_fees                                   0.778910
# btc_n_transactions_total                               0.698476
# btc_blocks_size                                        0.693590
# btc_n_unique_addresses                                 0.661161
# btc_n_transactions_excluding_chains_longer_than_100    0.565298
# btc_n_transactions                                     0.564382
# btc_avg_block_size                                     0.558899
# btc_n_transactions_excluding_popular                   0.554003
# btc_n_transactions_per_block                           0.539137
# btc_total_bitcoins                                     0.405682
# btc_median_confirmation_time                           0.274498
# btc_output_volume                                      0.105984
# btc_estimated_transaction_volume                       0.045032
# btc_cost_per_transaction_percent                      -0.012474
# btc_n_orphaned_blocks                                 -0.083591
# Name: btc_market_price, dtype: float64

# %%
import seaborn as sb

# %%
# Keep the ones with correlation > 0.80
sb.pairplot(bitcoin[['btc_market_price','btc_market_cap','btc_miners_revenue','btc_estimated_transaction_volume_usd','btc_hash_rate','btc_difficulty','btc_trade_volume','btc_cost_per_transaction']])

# %%
bitcoin.head()
# Out:
#    btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 0               0.0           2110700.0             0.0               0.0
# 1               0.0           2120200.0             0.0               0.0
# 2               0.0           2127600.0             0.0               0.0
# 3               0.0           2136100.0             0.0               0.0
# 4               0.0           2144750.0             0.0               0.0
#
#    btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 0              0.0            0.000216                    0.0
# 1              0.0            0.000282                    0.0
# 2              0.0            0.000227                    0.0
# 3              0.0            0.000319                    0.0
# 4              0.0            0.000223                    0.0
#
#    btc_n_transactions_per_block  btc_median_confirmation_time  btc_hash_rate  \
# 0                           1.0                           0.0       0.000032
# 1                           1.0                           0.0       0.000036
# 2                           1.0                           0.0       0.000028
# 3                           1.0                           0.0       0.000032
# 4                           1.0                           0.0       0.000033
#
#    ...  btc_cost_per_transaction_percent  btc_cost_per_transaction  \
# 0  ...                      25100.000000                       0.0
# 1  ...                        179.245283                       0.0
# 2  ...                       1057.142857                       0.0
# 3  ...                         64.582059                       0.0
# 4  ...                       1922.222222                       0.0
#
#    btc_n_unique_addresses  btc_n_transactions  btc_n_transactions_total  \
# 0                   252.0               252.0                   42613.0
# 1                   195.0               196.0                   42809.0
# 2                   150.0               150.0                   42959.0
# 3                   176.0               176.0                   43135.0
# 4                   176.0               176.0                   43311.0
#
#    btc_n_transactions_excluding_popular  \
# 0                                 252.0
# 1                                 196.0
# 2                                 150.0
# 3                                 176.0
# 4                                 176.0
#
#    btc_n_transactions_excluding_chains_longer_than_100  btc_output_volume  \
# 0                                              252.0              12600.0
# 1                                              196.0              14800.0
# 2                                              150.0               8100.0
# 3                                              176.0              29349.0
# 4                                              176.0               9101.0
#
#    btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# 0                              50.0                                   0.0
# 1                            5300.0                                   0.0
# 2                             700.0                                   0.0
# 3                           13162.0                                   0.0
# 4                             450.0                                   0.0
#
# [5 rows x 23 columns]

# %%
# Prepare the data for machine learning algorithms
bitcoin = train_set.drop("btc_market_price", axis=1) # drop labels for training set
bitcoin_labels = train_set["btc_market_price"].copy()

# %%
# find any rows with missing values
all_incomplete_rows = bitcoin[bitcoin.isnull().any(axis=1)]
len(all_incomplete_rows)
# Out:
# 0

# %%
# Select and train a model
type(bitcoin_labels)
# Out:
# pandas.core.series.Series

# %%
bitcoin_labels.head()
# Out:
# 1927    225.5400
# 163       0.0000
# 1957    257.9200
# 252       0.1955
# 2252    459.4000
# Name: btc_market_price, dtype: float64

# %%
bitcoin_tr = pd.DataFrame(bitcoin, columns=bitcoin.columns,
                          index=bitcoin.index)

# %%
bitcoin_tr.head()
# Out:
#       btc_total_bitcoins  btc_market_cap  btc_trade_volume  btc_blocks_size  \
# 1927          14235150.0    3.210596e+09      1.131495e+07     36420.000000
# 163            3627950.0    0.000000e+00      3.020442e+02         1.000000
# 1957          14345600.0    3.700017e+09      1.078173e+07     38418.000000
# 252            4460000.0    8.719300e+05      1.112144e+03         1.000000
# 2252          15469775.0    7.106815e+09      2.935363e+07     66022.678047
#
#       btc_avg_block_size  btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 1927            0.457110                    2.0                    713.000000
# 163             0.000887                    0.0                      1.000000
# 1957            0.405146                    7.0                   1356.000000
# 252             0.000475                    0.0                      1.000000
# 2252            0.728040                    0.0                   1387.537879
#
#       btc_median_confirmation_time  btc_hash_rate  btc_difficulty  ...  \
# 1927                      9.050000   3.359282e+05    4.758959e+10  ...
# 163                       0.000000   2.962137e-03    2.442132e+02  ...
# 1957                      7.333333   3.806471e+05    4.940201e+10  ...
# 252                       0.000000   2.582010e-02    3.091737e+03  ...
# 2252                      8.783333   1.172443e+06    1.786783e+11  ...
#
#       btc_cost_per_transaction_percent  btc_cost_per_transaction  \
# 1927                          1.722481                  6.493516
# 163                          66.298295                  0.000000
# 1957                          2.291255                  8.786112
# 252                          32.992619                  5.802827
# 2252                          1.385967                  8.360698
#
#       btc_n_unique_addresses  btc_n_transactions  btc_n_transactions_total  \
# 1927                240222.0            123893.0                70958001.0
# 163                    787.0               604.0                  100189.0
# 1957                250207.0            114310.0                74494223.0
# 252                    321.0               283.0                  138026.0
# 2252                376201.0            183155.0               124458860.0
#
#       btc_n_transactions_excluding_popular  \
# 1927                              117311.0
# 163                                  604.0
# 1957                              104771.0
# 252                                  283.0
# 2252                              213799.0
#
#       btc_n_transactions_excluding_chains_longer_than_100  btc_output_volume  \
# 1927                                            62608.0         1.277219e+06
# 163                                               460.0         6.319635e+04
# 1957                                            55637.0         1.036174e+06
# 252                                               283.0         6.517114e+04
# 2252                                           115683.0         2.223870e+06
#
#       btc_estimated_transaction_volume  btc_estimated_transaction_volume_usd
# 1927                     207085.000000                          4.670595e+07
# 163                       18402.000000                          0.000000e+00
# 1957                     169951.000000                          4.383364e+07
# 252                       25460.000000                          4.977000e+03
# 2252                     240501.291193                          1.104863e+08
#
# [5 rows x 22 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
# Out:
# Labels: [225.54, 0.0, 257.92, 0.1955, 459.4]

# %%
bitcoin_labels.describe()
# Out:
# count     2319.000000
# mean       909.481858
# std       2424.831058
# min          0.000000
# 25%          6.750000
# 50%        236.630000
# 75%        604.101250
# max      19498.683333
# Name: btc_market_price, dtype: float64

# %%
len(bitcoin_prepared)
# Out:
# 2319

# %%
# we can compute our mean squared error for all data
from sklearn.metrics import mean_squared_error

bitcoin_predictions = lin_reg.predict(bitcoin_prepared)
lin_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 14.802886729653117

# %%
from sklearn.metrics import mean_absolute_error

lin_mae = mean_absolute_error(bitcoin_labels, bitcoin_predictions)
lin_mae
# Out:
# 9.465112351872431

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=42, splitter='best')

# %%
bitcoin_predictions = tree_reg.predict(bitcoin_prepared)
tree_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 3.944834305067981e-05

# %%
bitcoin_predictions.shape
# Out:
# (2319,)

# %%
bitcoin_labels.shape
# Out:
# (2319,)

# %%
bitcoin_predictions[:5]
# Out:
# array([2.2554e+02, 0.0000e+00, 2.5792e+02, 1.9550e-01, 4.5940e+02])

# %%
bitcoin_labels[:5]
# Out:
# 1927    225.5400
# 163       0.0000
# 1957    257.9200
# 252       0.1955
# 2252    459.4000
# Name: btc_market_price, dtype: float64

# %%
# Fine tune your model
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg, bitcoin_prepared, bitcoin_labels,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [ 40.47726199  44.64219195  74.30418973  57.60742711  70.77149174
#   45.72919342  43.48326164 124.60898538 124.67725332  96.87414336]
# Mean: 72.31753996270982
# Standard deviation: 31.015754137844088

# %%
lin_scores = cross_val_score(lin_reg, bitcoin_prepared, bitcoin_labels,
                             scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [13.44780012 12.68827891 17.9122701  15.24642067 15.36135637 14.11347444
#  13.26138992 16.98074251 14.95594458 15.81042075]
# Mean: 14.977809839387893
# Standard deviation: 1.5751771237821608

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=10, random_state=42)
forest_reg.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
bitcoin_predictions = forest_reg.predict(bitcoin_prepared)
forest_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 32.39460608590074

# %%
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, bitcoin_prepared, bitcoin_labels,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [ 45.43164192  70.41668897  75.7945133   77.76877259  68.67793817
#   66.74950685  38.72395106  98.13464781 126.1418655   53.78805099]
# Mean: 72.16275771426906
# Standard deviation: 24.182085108320123

# %%
scores = cross_val_score(lin_reg, bitcoin_prepared, bitcoin_labels, scoring="neg_mean_squared_error", cv=10)
pd.Series(np.sqrt(-scores)).describe()
# Out:
# count    10.000000
# mean     14.977810
# std       1.660382
# min      12.688279
# 25%      13.614219
# 50%      15.101183
# 75%      15.698155
# max      17.912270
# dtype: float64

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(bitcoin_prepared, bitcoin_labels)
bitcoin_predictions = svm_reg.predict(bitcoin_prepared)
svm_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# 507.98074181263775

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# C:\Users\rudol\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=42,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_features': [2, 4, 6, 8],
#                           'n_estimators': [3, 10, 30]},
#                          {'bootstrap': [False], 'max_features': [2, 3, 4],
#                           'n_estimators': [3, 10]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='neg_mean_squared_error', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
bestPred = grid_search.best_estimator_
bestPred
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=8, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=30,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 328.89760689389425 {'max_features': 2, 'n_estimators': 3}
# 226.52958708368135 {'max_features': 2, 'n_estimators': 10}
# 188.86495124005026 {'max_features': 2, 'n_estimators': 30}
# 245.78314358686524 {'max_features': 4, 'n_estimators': 3}
# 170.8656202283302 {'max_features': 4, 'n_estimators': 10}
# 152.6791647537222 {'max_features': 4, 'n_estimators': 30}
# 184.633950139687 {'max_features': 6, 'n_estimators': 3}
# 133.16595583648825 {'max_features': 6, 'n_estimators': 10}
# 137.1092818217931 {'max_features': 6, 'n_estimators': 30}
# 184.12298971938006 {'max_features': 8, 'n_estimators': 3}
# 138.05496697013078 {'max_features': 8, 'n_estimators': 10}
# 126.84667425184998 {'max_features': 8, 'n_estimators': 30}
# 301.66215882806534 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 204.83297298675456 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 214.65064294285594 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# 161.40752862391685 {'bootstrap': False, 'max_features': 3, 'n_estimators': 10}
# 210.01599986614517 {'bootstrap': False, 'max_features': 4, 'n_estimators': 3}
# 156.97681799187936 {'bootstrap': False, 'max_features': 4, 'n_estimators': 10}

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.015166      0.001590         0.001197        0.000399
# 1        0.040294      0.000488         0.002586        0.000483
# 2        0.153190      0.015777         0.006190        0.001462
# 3        0.026727      0.002477         0.001000        0.000004
# 4        0.071020      0.006600         0.002790        0.000749
# 5        0.187712      0.001947         0.004788        0.000401
# 6        0.025140      0.000395         0.000998        0.000003
# 7        0.113696      0.017103         0.003192        0.001465
# 8        0.246370      0.003274         0.004974        0.000018
# 9        0.031509      0.000497         0.001603        0.000496
# 10       0.104905      0.001333         0.002001        0.000012
# 11       0.310572      0.002559         0.005785        0.000739
# 12       0.021143      0.000748         0.001601        0.000492
# 13       0.063032      0.001717         0.002793        0.000399
# 14       0.024535      0.000502         0.001402        0.000497
# 15       0.081977      0.000970         0.002587        0.000786
# 16       0.031915      0.001273         0.001595        0.000491
# 17       0.105127      0.003493         0.002593        0.000487
#
#    param_max_features param_n_estimators param_bootstrap  \
# 0                   2                  3             NaN
# 1                   2                 10             NaN
# 2                   2                 30             NaN
# 3                   4                  3             NaN
# 4                   4                 10             NaN
# 5                   4                 30             NaN
# 6                   6                  3             NaN
# 7                   6                 10             NaN
# 8                   6                 30             NaN
# 9                   8                  3             NaN
# 10                  8                 10             NaN
# 11                  8                 30             NaN
# 12                  2                  3           False
# 13                  2                 10           False
# 14                  3                  3           False
# 15                  3                 10           False
# 16                  4                  3           False
# 17                  4                 10           False
#
#                                                params  split0_test_score  \
# 0              {'max_features': 2, 'n_estimators': 3}     -126400.519164
# 1             {'max_features': 2, 'n_estimators': 10}      -41775.641012
# 2             {'max_features': 2, 'n_estimators': 30}      -37183.358750
# 3              {'max_features': 4, 'n_estimators': 3}      -24318.328798
# 4             {'max_features': 4, 'n_estimators': 10}      -27575.329491
# 5             {'max_features': 4, 'n_estimators': 30}      -26315.745416
# 6              {'max_features': 6, 'n_estimators': 3}      -13314.509284
# 7             {'max_features': 6, 'n_estimators': 10}      -15547.223495
# 8             {'max_features': 6, 'n_estimators': 30}      -22176.207522
# 9              {'max_features': 8, 'n_estimators': 3}      -23717.351548
# 10            {'max_features': 8, 'n_estimators': 10}      -14419.476629
# 11            {'max_features': 8, 'n_estimators': 30}      -16703.594083
# 12  {'bootstrap': False, 'max_features': 2, 'n_est...     -104305.189100
# 13  {'bootstrap': False, 'max_features': 2, 'n_est...      -44048.949121
# 14  {'bootstrap': False, 'max_features': 3, 'n_est...      -40576.627422
# 15  {'bootstrap': False, 'max_features': 3, 'n_est...      -25756.630627
# 16  {'bootstrap': False, 'max_features': 4, 'n_est...      -55937.841466
# 17  {'bootstrap': False, 'max_features': 4, 'n_est...      -35134.417675
#
#     split1_test_score  ...  mean_test_score  std_test_score  rank_test_score  \
# 0      -121108.108214  ...   -108173.635821    36132.399993               18
# 1       -29716.956120  ...    -51315.653824    21861.416474               15
# 2       -18897.001247  ...    -35669.969807    13631.285494               11
# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=200),
        'max_features': randint(low=1, high=8),
    }

forest_reg = RandomForestRegressor(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# C:\Users\rudol\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators='warn',
#                                                    n_jobs=None, oob_score=False,
#                                                    random_sta...
#                                                    warm_start=False),
#                    iid='warn', n_iter=10, n_jobs=None,
#                    param_distributions={'max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000020314786B08>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x0000020314641C08>},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=0)

# %%
rnd_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=7, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=180,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 129.54894480726975 {'max_features': 7, 'n_estimators': 180}
# 146.75162982061394 {'max_features': 5, 'n_estimators': 15}
# 162.43641442960623 {'max_features': 3, 'n_estimators': 72}
# 147.176472880209 {'max_features': 5, 'n_estimators': 21}
# 129.98545217497983 {'max_features': 7, 'n_estimators': 122}
# 161.68632457750775 {'max_features': 3, 'n_estimators': 75}
# 163.75330706169547 {'max_features': 3, 'n_estimators': 88}
# 139.30266928384196 {'max_features': 5, 'n_estimators': 100}
# 160.66955242302063 {'max_features': 3, 'n_estimators': 150}
# 242.6988396196054 {'max_features': 5, 'n_estimators': 2}

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([3.47338222e-01, 2.83223000e-01, 9.38763402e-05, 9.63062383e-02,
#        4.97226017e-02, 8.04770761e-07, 9.75432904e-04, 1.10841395e-04,
#        4.78315716e-03, 1.05474296e-02, 4.39643299e-02, 2.76721277e-04,
#        3.68711128e-04, 1.56624382e-02, 3.28129297e-03, 3.41171964e-04,
#        1.34860328e-01, 5.86058304e-04, 4.29431160e-04, 5.14312761e-04,
#        9.62911396e-05, 6.51730940e-03])

# %%
final_model = grid_search.best_estimator_

X_test = test_set.drop("btc_market_price", axis=1)
y_test = test_set["btc_market_price"].copy()

X_test_prepared = num_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 80.25246697234208

# %%
# We can compute a 95% confidence interval for the test RMSE:
from scipy import stats

# %%
confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
mean = squared_errors.mean()
m = len(squared_errors)

np.sqrt(stats.t.interval(confidence, m - 1,
                         loc=np.mean(squared_errors),
                         scale=stats.sem(squared_errors)))
# Out:
# array([ 53.02732457, 100.34450538])

# %%
zscore = stats.norm.ppf((1 + confidence) / 2)
zmargin = zscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - zmargin), np.sqrt(mean + zmargin)
# Out:
# (53.09879624861725, 100.30670340132573)
