# %%
import pandas as pd
import numpy as np

# %%
bitcoin=pd.read_csv('bitcoin_dataset.csv')

# %%
bitcoin.head()
# Out:
#                   Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2010-02-23 00:00:00               0.0           2110700.0             0.0
# 1  2010-02-24 00:00:00               0.0           2120200.0             0.0
# 2  2010-02-25 00:00:00               0.0           2127600.0             0.0
# 3  2010-02-26 00:00:00               0.0           2136100.0             0.0
# 4  2010-02-27 00:00:00               0.0           2144750.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000216
# 1               0.0              0.0            0.000282
# 2               0.0              0.0            0.000227
# 3               0.0              0.0            0.000319
# 4               0.0              0.0            0.000223
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                    0.0                           1.0
# ...

# %%
bitcoin.tail()
# Out:
#                      Date  btc_market_price  btc_total_bitcoins  \
# 2915  2018-02-16 00:00:00      10127.161667          16869150.0
# 2916  2018-02-17 00:00:00      10841.991667          16871012.5
# 2917  2018-02-18 00:00:00      10503.298333          16873037.5
# 2918  2018-02-19 00:00:00      11110.965000          16875062.5
# 2919  2018-02-20 00:00:00      11390.391667          16876825.0
#
#       btc_market_cap  btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 2915    1.708366e+11      8.665020e+08    157056.833478            0.989634
# 2916    1.829154e+11      9.735543e+08    157201.813038            0.973017
# 2917    1.772225e+11      1.377347e+09    157359.401239            0.972767
# 2918    1.874982e+11      1.020589e+09    157522.467859            1.006584
# 2919    1.922336e+11      1.258473e+09    157664.996336            1.010840
#
#       btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 2915                    0.0                   1195.783439
# ...

# %%
bitcoin.describe()
# Out:
#        btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# count       2920.000000        2.920000e+03    2.920000e+03      2.899000e+03
# mean         897.485562        1.152051e+07    1.443022e+10      8.231157e+07
# std         2400.159935        4.200938e+06    4.029263e+10      3.116642e+08
# min            0.000000        2.110700e+06    0.000000e+00      0.000000e+00
# 25%            6.768750        8.405100e+06    5.560588e+07      2.994316e+05
# 50%          236.310000        1.242910e+07    3.364730e+09      1.024364e+07
# 75%          603.909050        1.523764e+07    8.210042e+09      2.934823e+07
# max        19498.683333        1.687682e+07    3.265254e+11      5.352016e+09
#
#        btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# count      2920.000000         2920.000000            2920.000000
# mean      36058.374765            0.355733               0.362329
# std       44536.901058            0.356388               0.840614
# ...

# %%
bitcoin.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                      0
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                         0
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                            0
# btc_hash_rate                                           0
# btc_difficulty                                          0
# btc_miners_revenue                                      0
# btc_transaction_fees                                    0
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
bitcoin[bitcoin['btc_trade_volume'].isnull()]
# Out:
#                      Date  btc_market_price  btc_total_bitcoins  \
# 482   2011-06-20 00:00:00           17.3500           6605900.0
# 483   2011-06-21 00:00:00           15.5000           6617450.0
# 484   2011-06-22 00:00:00           15.0500           6630950.0
# 485   2011-06-23 00:00:00           16.0000           6642850.0
# 486   2011-06-24 00:00:00           16.7501           6654850.0
# 487   2011-06-25 00:00:00           17.6000           6662400.0
# 1302  2013-09-17 00:00:00          127.5600          11713200.0
# 1342  2013-10-27 00:00:00          189.0600          11910050.0
# 1536  2014-05-09 00:00:00          452.0200          12747700.0
# 1560  2014-06-02 00:00:00          631.4900          12846750.0
# 1561  2014-06-03 00:00:00          673.9000          12851450.0
# 1620  2014-08-01 00:00:00          601.9400          13088050.0
# 1622  2014-08-03 00:00:00          589.7900          13096075.0
# 1624  2014-08-05 00:00:00          580.2100          13102750.0
# ...

# %%
# Drop na's
bitcoin.dropna(inplace=True)

# %%
bitcoin[bitcoin['btc_trade_volume'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Date, btc_market_price, btc_total_bitcoins, btc_market_cap, btc_trade_volume, btc_blocks_size, btc_avg_block_size, btc_n_orphaned_blocks, btc_n_transactions_per_block, btc_median_confirmation_time, btc_hash_rate, btc_difficulty, btc_miners_revenue, btc_transaction_fees, btc_cost_per_transaction_percent, btc_cost_per_transaction, btc_n_unique_addresses, btc_n_transactions, btc_n_transactions_total, btc_n_transactions_excluding_popular, btc_n_transactions_excluding_chains_longer_than_100, btc_output_volume, btc_estimated_transaction_volume, btc_estimated_transaction_volume_usd]
# Index: []
#
# [0 rows x 24 columns]

# %%
bitcoin.shape
# Out:
# (2899, 24)

# %%
bitcoin.size
# Out:
# 69576

# %%
bitcoin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2899 entries, 0 to 2919
# Data columns (total 24 columns):
# Date                                                   2899 non-null object
# btc_market_price                                       2899 non-null float64
# btc_total_bitcoins                                     2899 non-null float64
# btc_market_cap                                         2899 non-null float64
# btc_trade_volume                                       2899 non-null float64
# btc_blocks_size                                        2899 non-null float64
# btc_avg_block_size                                     2899 non-null float64
# btc_n_orphaned_blocks                                  2899 non-null float64
# btc_n_transactions_per_block                           2899 non-null float64
# btc_median_confirmation_time                           2899 non-null float64
# btc_hash_rate                                          2899 non-null float64
# ...

# %%
# Drop the dates
bitcoin.drop(["Date"],axis=1,inplace=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
bitcoin.hist(bins=100, figsize=(20,15))
plt.show()

# %%
zero_market_price = bitcoin[bitcoin.btc_market_price == 0]
bitcoin.drop(zero_market_price.index,inplace=True)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
bitcoin.hist(bins=100, figsize=(20,15))
plt.show()

# %%
bitcoin.shape
# Out:
# (2724, 23)

# %%
bitcoin.size
# Out:
# 62652

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(bitcoin, test_size=0.2, random_state=42)

# %%
len(train_set)
# Out:
# 2179

# %%
train_set.head()
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 1847        290.880000          13947075.0    4.056925e+09      1.734290e+07
# 2263        448.510000          15510550.0    6.956637e+09      1.921468e+07
# 1180        123.749950          11169850.0    1.382268e+09      3.592511e+06
# 2582       1049.084488          16227287.5    1.690883e+10      5.871887e+07
# 881           9.200000           9520450.0    8.758814e+07      1.320447e+06
#
#       btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 1847     31889.000000            0.431849                    0.0
# 2263     67292.308494            0.706327                    1.0
# 1180      7742.000000            0.166721                    0.0
# 2582    107450.123614            0.977387                    0.0
# 881       1938.000000            0.099818                    0.0
#
#       btc_n_transactions_per_block  btc_median_confirmation_time  \
# ...

# %%
test_set.head()
# Out:
#       btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 2423        635.013937          15926212.5    1.015232e+10      1.463471e+07
# 1776        270.930000          13686975.0    3.708212e+09      5.310479e+07
# 1651        482.590000          13215900.0    6.377861e+09      1.032870e+07
# 2028        229.860000          14608800.0    3.357979e+09      1.267363e+07
# 786           5.190000           8816500.0    4.575764e+07      2.881116e+05
#
#       btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 2423      85918.69354            0.865468                    1.0
# 1776      27971.00000            0.296036                    1.0
# 1651      22247.00000            0.252555                    2.0
# 2028      44065.00000            0.632982                    1.0
# 786         930.00000            0.024548                    0.0
#
#       btc_n_transactions_per_block  btc_median_confirmation_time  \
# ...

# %%
corr_matrix = bitcoin.corr()

# %%
type(corr_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
corr_matrix
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.419454
# btc_market_cap                                              0.999806
# btc_trade_volume                                            0.865887
# btc_blocks_size                                             0.691909
# btc_avg_block_size                                          0.555366
# btc_n_orphaned_blocks                                      -0.094883
# btc_n_transactions_per_block                                0.534670
# btc_median_confirmation_time                                0.259010
# btc_hash_rate                                               0.903281
# btc_difficulty                                              0.899732
# btc_miners_revenue                                          0.985298
# btc_transaction_fees                                        0.776648
# ...

# %%
corr_matrix["btc_market_price"].sort_values(ascending=False)
# Out:
# btc_market_price                                       1.000000
# btc_market_cap                                         0.999806
# btc_miners_revenue                                     0.985298
# btc_estimated_transaction_volume_usd                   0.959671
# btc_hash_rate                                          0.903281
# btc_difficulty                                         0.899732
# btc_trade_volume                                       0.865887
# btc_cost_per_transaction                               0.832582
# btc_transaction_fees                                   0.776648
# btc_n_transactions_total                               0.697160
# btc_blocks_size                                        0.691909
# btc_n_unique_addresses                                 0.660364
# btc_n_transactions_excluding_chains_longer_than_100    0.561011
# btc_n_transactions                                     0.560943
# btc_avg_block_size                                     0.555366
# ...

# %%
import seaborn as sb

# %%
# Keep the ones with correlation > 0.80
sb.pairplot(bitcoin[['btc_market_price','btc_market_cap','btc_miners_revenue','btc_estimated_transaction_volume_usd','btc_hash_rate','btc_difficulty','btc_trade_volume','btc_cost_per_transaction']])

# %%
bitcoin.head()
# Out:
#      btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# 175          0.076900           3744250.0    287932.82500          923.0018
# 176          0.074000           3750900.0    277566.60000          206.7786
# 177          0.068800           3757900.0    258543.52000           51.8784
# 178          0.066700           3766250.0    251208.87500          293.9825
# 179          0.066899           3775450.0    252573.82955          731.0702
#
#      btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# 175              1.0            0.000959                    0.0
# 176              1.0            0.001973                    0.0
# 177              1.0            0.000715                    0.0
# 178              1.0            0.000649                    0.0
# 179              1.0            0.000528                    0.0
#
#      btc_n_transactions_per_block  btc_median_confirmation_time  \
# ...

# %%
# Prepare the data for machine learning algorithms
bitcoin = train_set.drop("btc_market_price", axis=1) # drop labels for training set
bitcoin_labels = train_set["btc_market_price"].copy()

# %%
# find any rows with missing values
all_incomplete_rows = bitcoin[bitcoin.isnull().any(axis=1)]
len(all_incomplete_rows)
# Out:
# 0

# %%
# Select and train a model
type(bitcoin_labels)
# Out:
# pandas.core.series.Series

# %%
bitcoin_labels.head()
# Out:
# 1847     290.880000
# 2263     448.510000
# 1180     123.749950
# 2582    1049.084488
# 881        9.200000
# Name: btc_market_price, dtype: float64

# %%
bitcoin_tr = pd.DataFrame(bitcoin, columns=bitcoin.columns,
                          index=bitcoin.index)

# %%
bitcoin_tr.head()
# Out:
#       btc_total_bitcoins  btc_market_cap  btc_trade_volume  btc_blocks_size  \
# 1847          13947075.0    4.056925e+09      1.734290e+07     31889.000000
# 2263          15510550.0    6.956637e+09      1.921468e+07     67292.308494
# 1180          11169850.0    1.382268e+09      3.592511e+06      7742.000000
# 2582          16227287.5    1.690883e+10      5.871887e+07    107450.123614
# 881            9520450.0    8.758814e+07      1.320447e+06      1938.000000
#
#       btc_avg_block_size  btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 1847            0.431849                    0.0                    702.000000
# 2263            0.706327                    1.0                   1481.161290
# 1180            0.166721                    0.0                    340.000000
# 2582            0.977387                    0.0                   2037.007353
# 881             0.099818                    0.0                    195.000000
#
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
        ('std_scaler', StandardScaler()),
    ])

bitcoin_num_tr = num_pipeline.fit_transform(bitcoin_tr)

# %%
len(bitcoin_num_tr)
# Out:
# 2179

# %%
type(bitcoin_num_tr)
# Out:
# numpy.ndarray

# %%
bitcoin_num_tr[:5]
# Out:
# array([[ 0.50266576, -0.27551764, -0.21838812, -0.14846803,  0.14799756,
#         -0.44476421, -0.02720981,  0.19133862, -0.34001145, -0.33111283,
#         -0.25138635, -0.42341787, -0.28036178, -0.29416223, -0.01407365,
#         -0.1158098 , -0.14609443, -0.15004858, -0.22352077, -0.36659774,
#         -0.33521014, -0.30898772],
#        [ 0.9256313 , -0.20755353, -0.2128079 ,  0.63403973,  0.91987587,
#          0.7214707 ,  1.10164833, -0.15858554, -0.03519682, -0.03999863,
#         -0.1198414 , -0.17679459, -0.38680941, -0.38734067,  0.78093261,
#          1.14999199,  0.60297938,  1.23553841,  1.03096212,  0.2293041 ,
#          0.31002238, -0.16377194],
#        [-0.24865451, -0.33820687, -0.25938111, -0.68218128, -0.59758506,
#         -0.44476421, -0.55167971,  0.02344572, -0.42743086, -0.43629762,
#         -0.33187419, -0.21603033, -0.35508916, -0.33638796, -0.72710357,
#         -0.5558331 , -0.66346233, -0.74970979, -0.61213164, -0.34652095,
# ...

# %%
bitcoin_prepared = bitcoin_num_tr

# %%
bitcoin_prepared.shape
# Out:
# (2179, 22)

# %%
bitcoin_prepared[:,0].min(),bitcoin_prepared[:,0].max()
# Out:
# (-2.257495642276081, 1.2952484937894195)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
# so here we finally fit our data
lin_reg.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin_reg.coef_
# Out:
# array([-1.10061120e+01,  2.47310311e+03,  2.12062824e+00, -8.84443171e+02,
#         5.44201889e+00, -7.48545768e-01, -9.57192747e+00,  2.47102685e+00,
#        -6.49799515e+01,  2.07902185e+01,  2.05576135e+01, -1.91996551e+01,
#         9.04809171e-01,  6.11343591e+01,  2.78343028e+01,  1.06963280e+01,
#         9.08319375e+02, -5.27426738e+00,  4.33779155e+00,  4.10886132e-01,
#         2.47914465e-01,  1.05614984e+01])

# %%
lin_reg.intercept_
# Out:
# 981.8728995473514

# %%
# let's try the full preprocessing pipeline on a few training instances
some_data = bitcoin.iloc[:5]
some_labels = bitcoin_labels.iloc[:5]
some_data_prepared = num_pipeline.transform(some_data)

print("Predictions:", lin_reg.predict(some_data_prepared))
print("Labels:\n", some_labels)
# Out:
# Predictions: [ 289.6052912   447.17840703  117.45009913 1052.74437635    5.32179529]
# Labels:
#  1847     290.880000
# 2263     448.510000
# 1180     123.749950
# 2582    1049.084488
# 881        9.200000
# Name: btc_market_price, dtype: float64

# %%
some_data_prepared
# Out:
# array([[ 0.50266576, -0.27551764, -0.21838812, -0.14846803,  0.14799756,
#         -0.44476421, -0.02720981,  0.19133862, -0.34001145, -0.33111283,
#         -0.25138635, -0.42341787, -0.28036178, -0.29416223, -0.01407365,
#         -0.1158098 , -0.14609443, -0.15004858, -0.22352077, -0.36659774,
#         -0.33521014, -0.30898772],
#        [ 0.9256313 , -0.20755353, -0.2128079 ,  0.63403973,  0.91987587,
#          0.7214707 ,  1.10164833, -0.15858554, -0.03519682, -0.03999863,
#         -0.1198414 , -0.17679459, -0.38680941, -0.38734067,  0.78093261,
#          1.14999199,  0.60297938,  1.23553841,  1.03096212,  0.2293041 ,
#          0.31002238, -0.16377194],
#        [-0.24865451, -0.33820687, -0.25938111, -0.68218128, -0.59758506,
#         -0.44476421, -0.55167971,  0.02344572, -0.42743086, -0.43629762,
#         -0.33187419, -0.21603033, -0.35508916, -0.33638796, -0.72710357,
#         -0.5558331 , -0.66346233, -0.74970979, -0.61213164, -0.34652095,
# ...

# %%
print("Labels:", list(some_labels))
# Out:
# Labels: [290.88, 448.51, 123.74995, 1049.0844875, 9.2]

# %%
bitcoin_labels.describe()
# Out:
# count     2179.000000
# mean       981.872900
# std       2540.973196
# min          0.060900
# 25%         11.290560
# 50%        252.440000
# 75%        620.515000
# max      19498.683333
# Name: btc_market_price, dtype: float64

# %%
len(bitcoin_prepared)
# Out:
# 2179

# %%
# we can compute our mean squared error for all data
from sklearn.metrics import mean_squared_error

bitcoin_predictions = lin_reg.predict(bitcoin_prepared)
lin_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 15.29172200835073

# %%
from sklearn.metrics import mean_absolute_error

lin_mae = mean_absolute_error(bitcoin_labels, bitcoin_predictions)
lin_mae
# Out:
# 9.81067212524955

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(random_state=42)
tree_reg.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=42, splitter='best')

# %%
bitcoin_predictions = tree_reg.predict(bitcoin_prepared)
tree_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
tree_rmse = np.sqrt(tree_mse)
tree_rmse
# Out:
# 3.569197625937794e-05

# %%
bitcoin_predictions.shape
# Out:
# (2179,)

# %%
bitcoin_labels.shape
# Out:
# (2179,)

# %%
bitcoin_predictions[:5]
# Out:
# array([ 290.88     ,  448.51     ,  123.74995  , 1049.0844875,
#           9.2      ])

# %%
bitcoin_labels[:5]
# Out:
# 1847     290.880000
# 2263     448.510000
# 1180     123.749950
# 2582    1049.084488
# 881        9.200000
# Name: btc_market_price, dtype: float64

# %%
# Fine tune your model
from sklearn.model_selection import cross_val_score

scores = cross_val_score(tree_reg, bitcoin_prepared, bitcoin_labels,
                         scoring="neg_mean_squared_error", cv=10)
tree_rmse_scores = np.sqrt(-scores)

# %%
def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(tree_rmse_scores)
# Out:
# Scores: [ 49.84366143  50.89587681  94.65017561  85.74536179  58.96975056
#   67.74868753  47.7286061   73.20265568 109.80407751  70.62160369]
# Mean: 70.92104567067142
# Standard deviation: 19.58588167367319

# %%
lin_scores = cross_val_score(lin_reg, bitcoin_prepared, bitcoin_labels,
                             scoring="neg_mean_squared_error", cv=10)
lin_rmse_scores = np.sqrt(-lin_scores)
display_scores(lin_rmse_scores)
# Out:
# Scores: [12.13283285 15.02765287 18.34180869 16.47248157 18.67787505 15.35375303
#  12.97364806 17.6641941  14.28693376 13.98948743]
# Mean: 15.492066740609289
# Standard deviation: 2.1335777521868695

# %%
from sklearn.ensemble import RandomForestRegressor

forest_reg = RandomForestRegressor(n_estimators=10, random_state=42)
forest_reg.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
bitcoin_predictions = forest_reg.predict(bitcoin_prepared)
forest_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
forest_rmse = np.sqrt(forest_mse)
forest_rmse
# Out:
# 26.752467178306205

# %%
from sklearn.model_selection import cross_val_score

forest_scores = cross_val_score(forest_reg, bitcoin_prepared, bitcoin_labels,
                                scoring="neg_mean_squared_error", cv=10)
forest_rmse_scores = np.sqrt(-forest_scores)
display_scores(forest_rmse_scores)
# Out:
# Scores: [ 65.54423535  20.81401115  47.11765692  38.98494708  69.92016157
#  100.87460483  28.62425668  66.34828413  79.91794885  62.36881814]
# Mean: 58.05149246990421
# Standard deviation: 23.091378382549742

# %%
scores = cross_val_score(lin_reg, bitcoin_prepared, bitcoin_labels, scoring="neg_mean_squared_error", cv=10)
pd.Series(np.sqrt(-scores)).describe()
# Out:
# count    10.000000
# mean     15.492067
# std       2.248988
# min      12.132833
# 25%      14.063849
# 50%      15.190703
# 75%      17.366266
# max      18.677875
# dtype: float64

# %%
from sklearn.svm import SVR

svm_reg = SVR(kernel="linear")
svm_reg.fit(bitcoin_prepared, bitcoin_labels)
bitcoin_predictions = svm_reg.predict(bitcoin_prepared)
svm_mse = mean_squared_error(bitcoin_labels, bitcoin_predictions)
svm_rmse = np.sqrt(svm_mse)
svm_rmse
# Out:
# 577.0414586782615

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30], 'max_features': [2, 4, 6, 8]},
    # then try 6 (2×3) combinations with bootstrap set as False
    {'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestRegressor(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='neg_mean_squared_error', return_train_score=True)
grid_search.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# C:\Users\rudol\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
# ...

# %%
grid_search.best_params_
# Out:
# {'max_features': 8, 'n_estimators': 30}

# %%
bestPred = grid_search.best_estimator_
bestPred
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=8, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=30,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 279.18067530520915 {'max_features': 2, 'n_estimators': 3}
# 209.57108702558233 {'max_features': 2, 'n_estimators': 10}
# 201.24719458165788 {'max_features': 2, 'n_estimators': 30}
# 242.28746743797169 {'max_features': 4, 'n_estimators': 3}
# 178.96301076631113 {'max_features': 4, 'n_estimators': 10}
# 170.99907962039893 {'max_features': 4, 'n_estimators': 30}
# 220.096896414589 {'max_features': 6, 'n_estimators': 3}
# 146.66389954467562 {'max_features': 6, 'n_estimators': 10}
# 133.341233397516 {'max_features': 6, 'n_estimators': 30}
# 185.71218010291537 {'max_features': 8, 'n_estimators': 3}
# 132.64598793131768 {'max_features': 8, 'n_estimators': 10}
# 123.65560441219138 {'max_features': 8, 'n_estimators': 30}
# 266.59776462172834 {'bootstrap': False, 'max_features': 2, 'n_estimators': 3}
# 210.76471200183855 {'bootstrap': False, 'max_features': 2, 'n_estimators': 10}
# 246.0539414924059 {'bootstrap': False, 'max_features': 3, 'n_estimators': 3}
# ...

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.015152      0.002029         0.001005        0.000012
# 1        0.040098      0.000983         0.002587        0.000484
# 2        0.125490      0.002976         0.004588        0.000488
# 3        0.019347      0.000798         0.001198        0.000399
# 4        0.064821      0.006213         0.003193        0.000747
# 5        0.186919      0.003767         0.004776        0.000393
# 6        0.025138      0.000737         0.001398        0.000488
# 7        0.082778      0.001410         0.002195        0.000399
# 8        0.243153      0.004665         0.005376        0.000490
# 9        0.030710      0.000755         0.001397        0.000489
# 10       0.100931      0.001459         0.002587        0.000483
# 11       0.306196      0.004154         0.004969        0.000015
# 12       0.019560      0.000474         0.001391        0.000480
# ...

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=200),
        'max_features': randint(low=1, high=8),
    }

forest_reg = RandomForestRegressor(random_state=42)
rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=10, cv=5, scoring='neg_mean_squared_error', random_state=42)
rnd_search.fit(bitcoin_prepared, bitcoin_labels)
# Out:
# C:\Users\rudol\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
# ...

# %%
rnd_search.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features=7, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=180,
#                       n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                       warm_start=False)

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(np.sqrt(-mean_score), params)
# Out:
# 124.77214849370718 {'max_features': 7, 'n_estimators': 180}
# 174.73217524169465 {'max_features': 5, 'n_estimators': 15}
# 167.43839931035882 {'max_features': 3, 'n_estimators': 72}
# 164.25127387486828 {'max_features': 5, 'n_estimators': 21}
# 127.09447135271368 {'max_features': 7, 'n_estimators': 122}
# 168.71998800801052 {'max_features': 3, 'n_estimators': 75}
# 170.0169593877148 {'max_features': 3, 'n_estimators': 88}
# 151.64807682966097 {'max_features': 5, 'n_estimators': 100}
# 168.76572765936086 {'max_features': 3, 'n_estimators': 150}
# 225.9500196466713 {'max_features': 5, 'n_estimators': 2}

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([3.49633572e-01, 2.66908632e-01, 9.59235027e-05, 9.23441071e-02,
#        2.53208294e-02, 9.95682456e-07, 2.05507489e-03, 2.20659218e-04,
#        4.69705953e-03, 8.78101371e-03, 5.57291304e-02, 9.55319290e-03,
#        4.14766237e-04, 9.48884673e-03, 4.97411431e-03, 1.72558714e-04,
#        1.25708741e-01, 9.62544763e-04, 5.86845536e-04, 2.29205232e-04,
#        6.58744442e-04, 4.14634426e-02])

# %%
final_model = grid_search.best_estimator_

X_test = test_set.drop("btc_market_price", axis=1)
y_test = test_set["btc_market_price"].copy()

X_test_prepared = num_pipeline.transform(X_test)
final_predictions = final_model.predict(X_test_prepared)

final_mse = mean_squared_error(y_test, final_predictions)
final_rmse = np.sqrt(final_mse)

# %%
final_rmse
# Out:
# 93.15596995685843

# %%
# We can compute a 95% confidence interval for the test RMSE:
from scipy import stats

# %%
confidence = 0.95
squared_errors = (final_predictions - y_test) ** 2
mean = squared_errors.mean()
m = len(squared_errors)

np.sqrt(stats.t.interval(confidence, m - 1,
                         loc=np.mean(squared_errors),
                         scale=stats.sem(squared_errors)))
# Out:
# array([ 43.94356809, 124.19755352])

# %%
zscore = stats.norm.ppf((1 + confidence) / 2)
zmargin = zscore * squared_errors.std(ddof=1) / np.sqrt(m)
np.sqrt(mean - zmargin), np.sqrt(mean + zmargin)
# Out:
# (44.114036583241464, 124.1371066745906)
